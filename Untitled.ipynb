# %%
a1 = c(51,45,43,46,50,56,41,47,44,40,48)
na1 = length(a1)
na1
a2 = c(42,47,52,45,54,47,46,45,50,49)
na2 = length(a2)
na2
# Out:
# [1] 11
# [1] 10

# %%
mean(a1) - mean(a2)
sd(a1)
sd(a2)
ep = sqrt(var(a1)/na1 + var(a1)/na2)
ep
# Out:
# [1] -1.245455
# [1] 4.676829
# [1] 3.591657
# [1] 2.043454

# %% [markdown]
# tc = (mean(a1) - mean(a2))/ep
# tc

# %%
t.test(a1, a2, paired = F, var.equal = F)
# Out:
# 	Welch Two Sample t-test
#
# data:  a1 and a2
# t = -0.68785, df = 18.522, p-value = 0.5001
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -5.041804  2.550895
# sample estimates:
# mean of x mean of y
#  46.45455  47.70000

# %%
28.44 - 26.60
# Out:
# [1] 1.84

# %%
ep  = sqrt((7.39^2) / 40 + (5.36^2) / 40)
ep
# Out:
# [1] 1.443448

# %% [markdown]
# tc = (28.44 - 26.60) / ep
# tc

# %%
-0.32 / sqrt((1-0.32^2)/8)
# Out:
# [1] -0.9553303
