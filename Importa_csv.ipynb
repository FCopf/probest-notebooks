# %% [markdown]
# ## Importar um arquivo .csv para o R

# %% [markdown]
# 1. Direcionar o R para o diretório onde encontra-se o arquivo

# %%
setwd("D:/OneDrive/Ensino")

# %% [markdown]
# 2. Verificar se a alteraçlão foi bem sucedida

# %%
getwd()
# Out:
# [1] "D:/OneDrive/Ensino"

# %% [markdown]
# 3. Verificar se seu arquivo de fato está na pasta

# %%
dir()
# Out:
# [1] "AntigasDisciplinas" "Graduacao"          "MaterialDidatico"
# [4] "PosGraduacao"       "qqnome.csv"

# %% [markdown]
# 5. Importar o arquivo para o R utilizando o comando 'read.csv'. Atentar para os argumentos `header`, `sep` e `dec`. Assitir à gravação da Aula Semana 11 para comentários sobre a importação.

# %%
ma = read.csv(file = "qqnome.csv", header = TRUE, sep = ";", dec = ",")
ma
# Out:
#    Ano  Sistema      Volume_reservatorio Chuva
# 1  2003 Guarapiranga 41.51                69.09
# 2  2004 Guarapiranga 38.89               101.92
# 3  2005 Guarapiranga 73.33               119.99
# 4  2006 Guarapiranga 71.69               123.57
# 5  2007 Guarapiranga 59.17               132.50
# 6  2008 Guarapiranga 61.81                91.33
# 7  2009 Guarapiranga 83.94               140.62
# 8  2010 Guarapiranga 81.12               130.73
# 9  2011 Guarapiranga 71.41                92.10
# 10 2012 Guarapiranga 72.45               121.62
# 11 2013 Guarapiranga 79.29                92.12
# 12 2014 Guarapiranga 61.04               100.87
# 13 2015 Guarapiranga 73.86               133.58
# 14 2016 Guarapiranga 81.17                99.32
# 15 2017 Guarapiranga 72.19               121.72
# 16 2018 Guarapiranga 71.96                63.84
# 17 2003 RioGrande    74.70                81.33
# 18 2004 RioGrande    83.84               143.03
# 19 2005 RioGrande    91.49               143.79
# ...
